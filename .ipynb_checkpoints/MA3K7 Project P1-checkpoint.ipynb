# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pandas as pd
import random

# %% [markdown]
# ### Functions

# %%
def converter(p1, p2):
    if p1 == 'A':
        if p2 == 'B':
            p3 = p4 = 'C'
        if p2 == 'C':
            p3 = p4 = 'B'
            
    if p1 == 'B':
        if p2 == 'A':
            p3 = p4 = 'C'
        if p2 == 'C':
            p3 = p4 = 'A'
            
    if p1 == 'C':
        if p2 == 'A':
            p3 = p4 = 'B'
        if p2 == 'B':
            p3 = p4 = 'A'

    return p3, p4

# %%
def collision(a, b, c):
    if a==b==0 or b==c==0 or a==c==0:
        return a, b, c
    particles = ['A'] * a + ['B'] * b + ['C'] * c
    p1 = p2 = 0
    while p1 == p2:
        p1, p2 = random.sample(particles, 2)
    particles.remove(p1)
    particles.remove(p2)
    p3, p4 = converter(p1, p2)
    particles.append(p3)
    particles.append(p4)

    return particles.count('A'), particles.count('B'), particles.count('C')

# %%
def collision_sim(a, b, c, n):
    t = np.linspace(0, n, n+1)
    a_vals = [a]
    b_vals = [b]
    c_vals = [c]
    for i in range(1, n+1):
        a, b, c = collision(a, b, c)
        a_vals.append(a)
        b_vals.append(b)
        c_vals.append(c)
        
    plt.step(t, a_vals, label='A')
    plt.step(t, b_vals, label='B')
    plt.step(t, c_vals, label='C')
    plt.title('Step Plot of particles over time')
    plt.grid(True)
    plt.legend()
    plt.show()
    
#     print(a_vals, b_vals, c_vals)

# %% [markdown]
# ### Main

# %%
collision_sim(15, 15, 15, 40000)
